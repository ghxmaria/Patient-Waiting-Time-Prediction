# %%
import os
working_directory = os.getcwd()
print(working_directory)
import category_encoders as ce

import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import statistics
import matplotlib.pyplot as plt
import statsmodels.api as sm

import plotly.offline as pyo
import plotly.graph_objs as go
import warnings
warnings.filterwarnings("ignore")
# Out:
# /Users/ghxclaire/A_Live Projects

# %%
df = pd.read_excel('OPD_project.xlsx')

# %%
df.head(5)
# Out:
#    Unnamed: 0        ID    Facility     Dept       Appt_DateTime  \
# 0           3  30534757  Facility_1     Surg 2019-01-02 08:20:00
# 1           9  30529244  Facility_1    Ortho 2019-01-02 08:15:00
# 2          10  29157451  Facility_1  Medical 2019-01-02 08:35:00
# 3          11  29749311  Facility_1    Ortho 2019-01-02 08:25:00
# 4          13  30384249  Facility_1   Opthal 2019-01-02 08:40:00
#
#            ChkIn_Time         PhySeenTime Include  ChkIn_NurSeen  \
# 0 2019-01-02 08:06:36 2019-01-02 08:17:19     Yes              4
# 1 2019-01-02 08:13:23 2019-01-02 08:37:05     Yes              0
# 2 2019-01-02 08:28:52 2019-01-02 08:37:21     Yes              7
# 3 2019-01-02 08:22:54 2019-01-02 08:41:09     Yes              2
# 4 2019-01-02 08:42:39 2019-01-02 08:46:51     Yes              1
#
#    NurSeen_PhySeen  WaitingTime  PhySeen_ChkOut  ChkIn_ChkOut  Duration  \
# 0                7           11               9            20        20
# 1               24           24              32            56        20
# 2                2            9              25            34        20
# 3               17           19              21            40        20
# 4                3            4              57            61        20
#
#   Phy_Name
# 0   Doc100
# 1    Doc38
# 2   Doc144
# 3    Doc68
# 4    Doc21

# %% [markdown]
# # Variable Description
#
# 1. ID: the unique identifier of each patient
# 2. Facility: this dataset includes 2 facilities(Facility 1 and Facility 3)
# 3. Dept: the departments of each health facility
# 4. Appt_DateTime: appointment datetime
# 5. ChkIn_Time: patients' check in time
# 6. PhySeenTime: the time when physicians see the patients
# 7. Include: a constant value 'Yes'
# 8. ChkIn_NurSeen: the time duration between check in time and nurse see the patient
# 9. NurSeen_PhySeen: the time duration between nurses see the patient and physicians see the patient
# 10. Physeen_ChkOut: the time duration between physicians see the patient and the patient check out.
# 11. ChkIn_ChkOut: the total check in and check out time
# 12. Duration
# 13. Phy_Name: names of physicians
# 14. 'WaitingTime': the patients' waiting time

# %%
df.isnull().sum()
# The data is cleaned.
# Out:
# Unnamed: 0         0
# ID                 0
# Facility           0
# Dept               0
# Appt_DateTime      0
# ChkIn_Time         0
# PhySeenTime        0
# Include            0
# ChkIn_NurSeen      0
# NurSeen_PhySeen    0
# WaitingTime        0
# PhySeen_ChkOut     0
# ChkIn_ChkOut       0
# Duration           0
# Phy_Name           0
# dtype: int64

# %%
# Drop the first unnamed column because it contains meaningless indexes. 
df = df.iloc[: , 1:]

# %% [markdown]
# # Data cleaning and exploration

# %% [markdown]
# ## Appointment time

# %% [markdown]
# ### Create new feature: Appt_Count
# Appt_Count: number of appointments per day per doctor

# %%
def add_appt_count(df):
    df['Appt_Date'] = df['Appt_DateTime'].dt.date
    df_count = df.groupby(['Appt_Date', 'Phy_Name']).count()['ID'].reset_index()
    df_count.columns = ['Appt_Date', 'Phy_Name', 'Appt_Count']
    df = df.merge(df_count, on=['Appt_Date', 'Phy_Name'], how='left')
    return df

# %%
df = add_appt_count(df)

# %% [markdown]
# ### Create new features from datetime column

# %%
# Functions to extract the month, week, day, Day of week, hour and minutes information from the datetime columns.
def extract_month(col):
    new_col = col.dt.month
    return new_col

def extract_week(col):
    new_col = col.dt.isocalendar().week
    return new_col

def extract_day(col):
    new_col = col.dt.isocalendar().week
    return new_col

def extract_dayofweek(col):
    new_col = col.dt.dayofweek
    return new_col

def extract_hour(col):
    new_col = col.dt.hour
    return new_col

def extract_minutes(col):
    new_col = col.dt.minute
    return new_col

# %%
# Create new columns to reflect the month, week, day, Day of week, hour and minutes information.
df['Appt_DateTime_month'] = extract_month(df['Appt_DateTime'])
df['Appt_DateTime_week'] = extract_week(df['Appt_DateTime'])
df['Appt_DateTime_day'] = extract_day(df['Appt_DateTime'])
df['Appt_DateTime_dayofweek'] = extract_dayofweek(df['Appt_DateTime'])
df['Appt_DateTime_hour'] = extract_hour(df['Appt_DateTime'])

# %%
df['ChkIn_Time_month'] = extract_month(df['ChkIn_Time'])
df['ChkIn_Time_week'] = extract_week(df['ChkIn_Time'])
df['ChkIn_Time_day'] = extract_day(df['ChkIn_Time'])
df['ChkIn_Time_dayofweek'] = extract_dayofweek(df['ChkIn_Time'])
df['ChkIn_Time_hour'] = extract_hour(df['ChkIn_Time'])

# %%
df['PhySeenTime_month'] = extract_month(df['PhySeenTime'])
df['PhySeenTime_week'] = extract_week(df['PhySeenTime'])
df['PhySeenTime_day'] = extract_day(df['PhySeenTime'])
df['PhySeenTime_dayofweek'] = extract_dayofweek(df['PhySeenTime'])
df['PhySeenTime_hour'] = extract_hour(df['PhySeenTime'])

# %% [markdown]
# ### Number of Appointments by Month
# - October, November and December are the three busiest months, while June has the least number of appointments.

# %%
months = df['Appt_DateTime_month'].value_counts()

plt.figure(figsize=(10,5))

ax = sns.barplot(x=months.index,y=months.values,alpha=0.8) # alpha is how big the barplot should be there.
ax.bar_label(ax.containers[0])

plt.title('Month of the appointment')
plt.ylabel('Number of Appointments',fontsize=12)
plt.xlabel('Month',fontsize=12)
plt.show()

# %% [markdown]
# ### Number of Appointments by Week
# - Patients can make appointments on Monday, Tuesday, Wednesday, Saturday and Sunday.
# - Tuesday is the busiest day of the week.

# %%
weeks = df['Appt_DateTime_dayofweek'].value_counts()

plt.figure(figsize=(10,5))
ax = sns.barplot(x=weeks.index,y=weeks.values,alpha=0.8) 
ax.bar_label(ax.containers[0])

# alpha is how big the barplot should be there.
plt.title('Weekday of the appointment')
plt.ylabel('Number of Appointments',fontsize=12)
plt.xlabel('DayofWeek',fontsize=12)
plt.show()

# %% [markdown]
# ### Number of the Appointment by Hour
# - Appointment time ranges from 7am to 3pm.
# - 9am is the busiest hour of the day.
# - 8am - 11am is the busiest appointment period.
# - 7am and 3pm have very few appointments compared to other time periods due to special patient conditions.

# %%
hour = df['Appt_DateTime_hour'].value_counts()

plt.figure(figsize=(10,5))
ax = sns.barplot(x=hour.index,y=hour.values,alpha=0.8) 
ax.bar_label(ax.containers[0])

plt.title('Hour of the appointment')
plt.ylabel('Number of Appointments',fontsize=12)
plt.xlabel('Hour of the day',fontsize=12)
plt.show()

# %% [markdown]
# ## Continuous Target variable: WaitingTime

# %%
df['WaitingTime'].describe()
# Out:
# count    28184.000000
# mean        30.874716
# std         67.778451
# min          0.000000
# 25%         11.000000
# 50%         22.000000
# 75%         40.000000
# max      10122.000000
# Name: WaitingTime, dtype: float64

# %% [markdown]
# ### Check the outliers

# %%
df_10122= df.loc[(df['WaitingTime'] == 10122)]

display(df_10122.head())
# Out:
#              ID    Facility     Dept       Appt_DateTime          ChkIn_Time  \
# 17324  34091076  Facility_1  Medical 2019-09-15 14:10:00 2019-09-15 13:54:11
#
#               PhySeenTime Include  ChkIn_NurSeen  NurSeen_PhySeen  \
# 17324 2019-09-22 14:36:30     Yes             96            10026
#
#        WaitingTime  ...  ChkIn_Time_month  ChkIn_Time_week  ChkIn_Time_day  \
# 17324        10122  ...                 9               37              37
#
#       ChkIn_Time_dayofweek ChkIn_Time_hour  PhySeenTime_month  \
# 17324                    6              13                  9
#
#        PhySeenTime_week  PhySeenTime_day  PhySeenTime_dayofweek  \
# 17324                38               38                      6
#
#        PhySeenTime_hour
# 17324                14
#
# [1 rows x 31 columns]

# %% [markdown]
# * CustomerID 34091076 had the maximum WaitingTime, which is 10,122 minutes and round to 7 days.
# * The CustomerID 34091076's PhySeen_ChkOut is 0, and ChkIn_ChkOut is 0.
# * The patient's Physician name is Doc75, and the patient belongs to medical department.
# * The data shows that patient 34091076 was not be able to see the doctor on the appointment day and show up 7 days later.
# * It is an exception and should be elimiated.

# %%
# Drop the outlier:
df.drop(df[df['WaitingTime'] ==10122].index, inplace=True)

# %%
df_1541= df.loc[(df['WaitingTime'] == 1541)]
display(df_1541.head().T)
# Out:
#                                         1222
# ID                                  30354724
# Facility                          Facility_1
# Dept                                 Medical
# Appt_DateTime            2019-01-16 13:55:00
# ChkIn_Time               2019-01-16 08:19:39
# PhySeenTime              2019-01-17 10:00:00
# Include                                  Yes
# ChkIn_NurSeen                           1541
# NurSeen_PhySeen                            0
# WaitingTime                             1541
# PhySeen_ChkOut                             0
# ChkIn_ChkOut                               0
# Duration                                  30
# Phy_Name                               Doc42
# Appt_Date                         2019-01-16
# Appt_Count                                 9
# Appt_DateTime_month                        1
# Appt_DateTime_week                         3
# Appt_DateTime_day                          3
# Appt_DateTime_dayofweek                    2
# Appt_DateTime_hour                        13
# ChkIn_Time_month                           1
# ChkIn_Time_week                            3
# ChkIn_Time_day                             3
# ChkIn_Time_dayofweek                       2
# ChkIn_Time_hour                            8
# PhySeenTime_month                          1
# PhySeenTime_week                           3
# PhySeenTime_day                            3
# PhySeenTime_dayofweek                      3
# PhySeenTime_hour                          10

# %% [markdown]
# * Now CustomerID 30354724 has the maximum WaitingTime, which is 1,541 minutes and equals to 25.68 hours. The CustomerID 30354724's PhySeen_ChkOut is 0, and ChkIn_ChkOut is 0. The patient's Physician name is Doc42, and the patient belongs to medical department.
# * After checking this row, we can see that the patient was not able to see the doctor on the appointment day and
# came the day after.
# * Again it might be due to some unexpected reasons, so this row should be elimiated.

# %%
# Drop the outlier:
df.drop(df[df['WaitingTime'] ==1541].index, inplace=True)

# %%
df['WaitingTime'].quantile([.2,0.75,0.90,0.95,0.97,0.98,0.99,0.999])
# Out:
# 0.200      9.000
# 0.750     40.000
# 0.900     65.000
# 0.950     83.000
# 0.970     97.000
# 0.980    109.000
# 0.990    133.190
# 0.999    316.638
# Name: WaitingTime, dtype: float64

# %% [markdown]
# ### Check the extreme long waiting time (0.1% tail of data)

# %%
df_ExtremeWaitingTime=df.loc[(df['WaitingTime'] > 316)]
df_ExtremeWaitingTime
# Out:
#              ID    Facility     Dept       Appt_DateTime          ChkIn_Time  \
# 84     30130229  Facility_1  Medical 2019-01-02 09:55:00 2019-01-02 09:56:44
# 494    30681308  Facility_1     Surg 2019-01-08 08:00:00 2019-01-08 07:49:23
# 840    29233382  Facility_1  Medical 2019-01-13 08:50:00 2019-01-13 08:22:59
# 4204   29440316  Facility_1    Derma 2019-02-24 12:50:00 2019-02-24 08:57:33
# 4295   31432050  Facility_1    Ortho 2019-02-25 08:00:00 2019-02-25 08:12:47
# 5356   31784141  Facility_1  Medical 2019-03-10 08:40:00 2019-03-10 08:45:30
# 5573   31310736  Facility_1    Derma 2019-03-12 12:30:00 2019-03-12 07:59:34
# 5607   31014853  Facility_1    Derma 2019-03-12 12:00:00 2019-03-12 08:21:12
# 7538   32204900  Facility_1    Derma 2019-04-08 09:20:00 2019-04-08 09:12:37
# 7629   31951541  Facility_1    Derma 2019-04-09 12:50:00 2019-04-09 10:50:03
# 10059  33119763  Facility_1    Derma 2019-05-19 10:31:00 2019-05-19 08:22:59
# 10232  33178634  Facility_1     Surg 2019-05-22 08:00:00 2019-05-22 08:12:37
# 11245  33258757  Facility_1    Derma 2019-06-18 09:13:00 2019-06-18 09:07:10
# 12053  33644521  Facility_1    Derma 2019-07-01 12:00:00 2019-07-01 09:00:22
# 12410  30785061  Facility_1    Derma 2019-07-07 09:16:00 2019-07-07 09:17:18
# 12551  34091079  Facility_1  Medical 2019-07-09 12:40:00 2019-07-09 08:28:37
# 12558  33943864  Facility_1    Derma 2019-07-09 13:45:00 2019-07-09 08:54:58
# 12560  33943483  Facility_1    Derma 2019-07-09 13:21:00 2019-07-09 08:55:41
# 12654  34039721  Facility_1    Ortho 2019-07-10 08:10:00 2019-07-10 08:14:09
# 12951  34169207  Facility_1    Psych 2019-07-16 11:40:00 2019-07-16 08:55:04
# 12963  33025639  Facility_1    Derma 2019-07-16 08:52:00 2019-07-16 09:02:09
# 13043  30680814  Facility_1    Derma 2019-07-17 09:40:00 2019-07-17 09:53:35
# 13044  31015795  Facility_1    Derma 2019-07-17 10:00:00 2019-07-17 09:55:21
# 14334  31899254  Facility_1    Derma 2019-08-06 09:20:00 2019-08-06 09:35:30
# 17825  35257124  Facility_1  Medical 2019-09-26 08:30:00 2019-09-26 08:16:18
# 20561  36491812  Facility_1   Nephro 2019-10-23 10:00:00 2019-10-23 10:14:08
# 21383  35975741  Facility_1    Ortho 2019-10-30 08:30:00 2019-10-30 08:29:14
# 23131  36794531  Facility_1    Gynae 2019-11-13 09:00:00 2019-11-13 08:43:28
# 23879  35880467  Facility_1     Surg 2019-11-19 08:00:00 2019-11-19 07:57:00
#
#               PhySeenTime Include  ChkIn_NurSeen  NurSeen_PhySeen  \
# 84    2019-01-02 15:13:34     Yes             20              297
# 494   2019-01-08 13:24:06     Yes              0              335
# 840   2019-01-13 15:19:04     Yes             24              393
# 4204  2019-02-24 15:19:04     Yes             24              358
# 4295  2019-02-25 13:41:59     Yes             22              307
# 5356  2019-03-10 14:23:49     Yes             12              326
# 5573  2019-03-12 13:26:20     Yes              5              322
# 5607  2019-03-12 16:34:49     Yes             24              469
# 7538  2019-04-08 15:13:10     Yes             26              335
# 7629  2019-04-09 16:07:34     Yes              2              315
# 10059 2019-05-19 14:08:55     Yes              0                0
# 10232 2019-05-22 13:45:36     Yes             15              318
# 11245 2019-06-18 14:24:57     Yes            150              167
# 12053 2019-07-01 14:22:39     Yes              8              314
# 12410 2019-07-07 16:05:47     Yes             17              391
# 12551 2019-07-09 13:57:22     Yes              0                0
# 12558 2019-07-09 14:37:45     Yes            345               -2
# 12560 2019-07-09 16:05:07     Yes             14              416
# 12654 2019-07-10 14:36:24     Yes              0                0
# 12951 2019-07-16 14:17:43     Yes             21              301
# 12963 2019-07-16 15:15:05     Yes             17              356
# 13043 2019-07-17 15:35:25     Yes              8              334
# 13044 2019-07-17 15:37:45     Yes              9              333
# 14334 2019-08-06 15:03:31     Yes             62              266
# 17825 2019-09-26 15:04:39     Yes             30              378
# 20561 2019-10-23 17:20:46     Yes              0                0
# 21383 2019-10-30 16:32:51     Yes             32              451
# 23131 2019-11-13 15:57:39     Yes              2              432
# 23879 2019-11-19 13:30:50     Yes             17              316
#
#        WaitingTime  ...  ChkIn_Time_month  ChkIn_Time_week  ChkIn_Time_day  \
# 84             317  ...                 1                1               1
# 494            335  ...                 1                2               2
# 840            417  ...                 1                2               2
# 4204           382  ...                 2                8               8
# 4295           329  ...                 2                9               9
# 5356           338  ...                 3               10              10
# 5573           327  ...                 3               11              11
# 5607           493  ...                 3               11              11
# 7538           361  ...                 4               15              15
# 7629           317  ...                 4               15              15
# 10059          346  ...                 5               20              20
# 10232          333  ...                 5               21              21
# 11245          317  ...                 6               25              25
# 12053          322  ...                 7               27              27
# 12410          408  ...                 7               27              27
# 12551          329  ...                 7               28              28
# 12558          343  ...                 7               28              28
# 12560          430  ...                 7               28              28
# 12654          382  ...                 7               28              28
# 12951          322  ...                 7               29              29
# 12963          373  ...                 7               29              29
# 13043          342  ...                 7               29              29
# 13044          342  ...                 7               29              29
# 14334          328  ...                 8               32              32
# 17825          408  ...                 9               39              39
# 20561          426  ...                10               43              43
# 21383          483  ...                10               44              44
# 23131          434  ...                11               46              46
# 23879          333  ...                11               47              47
#
#       ChkIn_Time_dayofweek ChkIn_Time_hour  PhySeenTime_month  \
# 84                       2               9                  1
# 494                      1               7                  1
# 840                      6               8                  1
# 4204                     6               8                  2
# 4295                     0               8                  2
# 5356                     6               8                  3
# 5573                     1               7                  3
# 5607                     1               8                  3
# 7538                     0               9                  4
# 7629                     1              10                  4
# 10059                    6               8                  5
# 10232                    2               8                  5
# 11245                    1               9                  6
# 12053                    0               9                  7
# 12410                    6               9                  7
# 12551                    1               8                  7
# 12558                    1               8                  7
# 12560                    1               8                  7
# 12654                    2               8                  7
# 12951                    1               8                  7
# 12963                    1               9                  7
# 13043                    2               9                  7
# 13044                    2               9                  7
# 14334                    1               9                  8
# 17825                    3               8                  9
# 20561                    2              10                 10
# 21383                    2               8                 10
# 23131                    2               8                 11
# 23879                    1               7                 11
#
#        PhySeenTime_week  PhySeenTime_day  PhySeenTime_dayofweek  \
# 84                    1                1                      2
# 494                   2                2                      1
# 840                   2                2                      6
# 4204                  8                8                      6
# 4295                  9                9                      0
# 5356                 10               10                      6
# 5573                 11               11                      1
# 5607                 11               11                      1
# 7538                 15               15                      0
# 7629                 15               15                      1
# 10059                20               20                      6
# 10232                21               21                      2
# 11245                25               25                      1
# 12053                27               27                      0
# 12410                27               27                      6
# 12551                28               28                      1
# 12558                28               28                      1
# 12560                28               28                      1
# 12654                28               28                      2
# 12951                29               29                      1
# 12963                29               29                      1
# 13043                29               29                      2
# 13044                29               29                      2
# 14334                32               32                      1
# 17825                39               39                      3
# 20561                43               43                      2
# 21383                44               44                      2
# 23131                46               46                      2
# 23879                47               47                      1
#
#        PhySeenTime_hour
# 84                   15
# 494                  13
# 840                  15
# 4204                 15
# 4295                 13
# 5356                 14
# 5573                 13
# 5607                 16
# 7538                 15
# 7629                 16
# 10059                14
# 10232                13
# 11245                14
# 12053                14
# 12410                16
# 12551                13
# 12558                14
# 12560                16
# 12654                14
# 12951                14
# 12963                15
# 13043                15
# 13044                15
# 14334                15
# 17825                15
# 20561                17
# 21383                16
# 23131                15
# 23879                13
#
# [29 rows x 31 columns]

# %%
# Check the extreme long waiting time dataset (WaitingTime>317)
df_ExtremeWaitingTime.groupby('Facility')['WaitingTime'].describe()

# Extreme long waiting time suitions appears in facility 1.
# The dataset has a mean WaitingTime of 366 minutes, which equals to 6.1 hours.
# Out:
#             count        mean        std    min    25%    50%    75%    max
# Facility
# Facility_1   29.0  366.103448  50.580449  317.0  329.0  342.0  408.0  493.0

# %%
# check the extreme waiting time dataset:

df_ExtremeWaitingTime['Dept'].value_counts()

# Extreme long waiting time appears 15 out of 29 times in dermatology department.
# Out:
# Derma      15
# Medical     5
# Surg        3
# Ortho       3
# Psych       1
# Nephro      1
# Gynae       1
# Name: Dept, dtype: int64

# %%
df_ExtremeWaitingTime['Appt_DateTime_month'].value_counts()
# Extreme long waiting time appears 10 times in July.
# Out:
# 7     10
# 1      3
# 3      3
# 2      2
# 4      2
# 5      2
# 10     2
# 11     2
# 6      1
# 8      1
# 9      1
# Name: Appt_DateTime_month, dtype: int64

# %%
df_ExtremeWaitingTime['Appt_DateTime_dayofweek'].value_counts()
# Extreme long waiting time appears 12 times on Tuesday.
# Out:
# 1    12
# 2     8
# 6     5
# 0     3
# 3     1
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_ExtremeWaitingTime['Appt_DateTime_hour'].value_counts()
# Extreme long waiting time appears when their appointment time is around 8am -9 am.
# Out:
# 8     10
# 9      7
# 12     6
# 10     3
# 13     2
# 11     1
# Name: Appt_DateTime_hour, dtype: int64

# %%
# Check the distribution of the extream long waiting time dataset
df_ExtremeWaitingTime['WaitingTime'].quantile([.2,0.5,0.7,0.75,0.90,0.95,0.99])
# Out:
# 0.20    327.6
# 0.50    342.0
# 0.70    382.0
# 0.75    408.0
# 0.90    430.8
# 0.95    463.4
# 0.99    490.2
# Name: WaitingTime, dtype: float64

# %%
# Check the extreme data: 

df_430 = df.loc[(df['WaitingTime'] >= 430)]

display(df_430.head())

# After checking these rows, we can see that the patient wait until the end of the day to see the doctor.
# The PhySeen_ChkOut ranges from 0 to 5 minutes, Phy_Name are Doc43, Doctor 142 and Doctor 132
# Doctor 43 belongs to dermatology department.
# Doctor 142 belongs to orthopedic department.
# Doctor 132 belongs to Gynecology department.
# Out:
#              ID    Facility   Dept       Appt_DateTime          ChkIn_Time  \
# 5607   31014853  Facility_1  Derma 2019-03-12 12:00:00 2019-03-12 08:21:12
# 12560  33943483  Facility_1  Derma 2019-07-09 13:21:00 2019-07-09 08:55:41
# 21383  35975741  Facility_1  Ortho 2019-10-30 08:30:00 2019-10-30 08:29:14
# 23131  36794531  Facility_1  Gynae 2019-11-13 09:00:00 2019-11-13 08:43:28
#
#               PhySeenTime Include  ChkIn_NurSeen  NurSeen_PhySeen  \
# 5607  2019-03-12 16:34:49     Yes             24              469
# 12560 2019-07-09 16:05:07     Yes             14              416
# 21383 2019-10-30 16:32:51     Yes             32              451
# 23131 2019-11-13 15:57:39     Yes              2              432
#
#        WaitingTime  ...  ChkIn_Time_month  ChkIn_Time_week  ChkIn_Time_day  \
# 5607           493  ...                 3               11              11
# 12560          430  ...                 7               28              28
# 21383          483  ...                10               44              44
# 23131          434  ...                11               46              46
#
#       ChkIn_Time_dayofweek ChkIn_Time_hour  PhySeenTime_month  \
# 5607                     1               8                  3
# 12560                    1               8                  7
# 21383                    2               8                 10
# 23131                    2               8                 11
#
#        PhySeenTime_week  PhySeenTime_day  PhySeenTime_dayofweek  \
# 5607                 11               11                      1
# 12560                28               28                      1
# 21383                44               44                      2
# 23131                46               46                      2
#
#        PhySeenTime_hour
# 5607                 16
# 12560                16
# 21383                16
# 23131                15
#
# [4 rows x 31 columns]

# %%
df['WaitingTime'].describe()
# Out:
# count    28182.000000
# mean        30.463062
# std         29.994936
# min          0.000000
# 25%         11.000000
# 50%         22.000000
# 75%         40.000000
# max        493.000000
# Name: WaitingTime, dtype: float64

# %%
df.drop(df_ExtremeWaitingTime.index,axis=0,inplace=True)

# %%
df['WaitingTime'].quantile([.2,0.5,0.7,0.75,0.90,0.95,0.99])
# Out:
# 0.20      9.0
# 0.50     22.0
# 0.70     36.0
# 0.75     40.0
# 0.90     64.8
# 0.95     82.0
# 0.99    130.0
# Name: WaitingTime, dtype: float64

# %% [markdown]
# ### Check the dataset with long waiting time(1% tail value)

# %%
df_LongWaitingTime=df.loc[(df['WaitingTime'] >= 133)]
df_LongWaitingTime
# Out:
#              ID    Facility     Dept       Appt_DateTime          ChkIn_Time  \
# 148    30300889  Facility_1      ANC 2019-01-03 09:00:00 2019-01-03 09:00:11
# 573    30658617  Facility_1    Gynae 2019-01-09 09:00:00 2019-01-09 08:58:18
# 905    30475701  Facility_1     Surg 2019-01-14 09:20:00 2019-01-14 09:03:14
# 908    30495712  Facility_1     Surg 2019-01-14 09:40:00 2019-01-14 09:46:44
# 923    30729170  Facility_1     Surg 2019-01-14 10:20:00 2019-01-14 10:29:38
# ...         ...         ...      ...                 ...                 ...
# 26473  37664089  Facility_1  Medical 2019-12-16 12:00:00 2019-12-16 11:59:41
# 26618  37169482  Facility_1     Surg 2019-12-17 10:00:00 2019-12-17 10:00:02
# 27535  35762498  Facility_1  Medical 2019-12-25 11:00:00 2019-12-25 10:28:18
# 27982  38106770  Facility_1  Medical 2019-12-30 10:10:00 2019-12-30 10:02:17
# 27990  37759785  Facility_1  Medical 2019-12-30 12:20:00 2019-12-30 11:50:56
#
#               PhySeenTime Include  ChkIn_NurSeen  NurSeen_PhySeen  \
# 148   2019-01-03 12:11:53     Yes              5              186
# 573   2019-01-09 12:02:20     Yes              7              177
# 905   2019-01-14 11:59:42     Yes             14              162
# 908   2019-01-14 12:11:45     Yes             31              114
# 923   2019-01-14 13:26:02     Yes             19              158
# ...                   ...     ...            ...              ...
# 26473 2019-12-16 14:18:43     Yes              3              136
# 26618 2019-12-17 12:23:43     Yes             13              130
# 27535 2019-12-25 15:08:38     Yes              1              279
# 27982 2019-12-30 14:03:55     Yes              5              236
# 27990 2019-12-30 14:17:16     Yes              9              138
#
#        WaitingTime  ...  ChkIn_Time_month  ChkIn_Time_week  ChkIn_Time_day  \
# 148            191  ...                 1                1               1
# 573            184  ...                 1                2               2
# 905            176  ...                 1                3               3
# 908            145  ...                 1                3               3
# 923            177  ...                 1                3               3
# ...            ...  ...               ...              ...             ...
# 26473          139  ...                12               51              51
# 26618          143  ...                12               51              51
# 27535          280  ...                12               52              52
# 27982          241  ...                12                1               1
# 27990          147  ...                12                1               1
#
#       ChkIn_Time_dayofweek ChkIn_Time_hour  PhySeenTime_month  \
# 148                      3               9                  1
# 573                      2               8                  1
# 905                      0               9                  1
# 908                      0               9                  1
# 923                      0              10                  1
# ...                    ...             ...                ...
# 26473                    0              11                 12
# 26618                    1              10                 12
# 27535                    2              10                 12
# 27982                    0              10                 12
# 27990                    0              11                 12
#
#        PhySeenTime_week  PhySeenTime_day  PhySeenTime_dayofweek  \
# 148                   1                1                      3
# 573                   2                2                      2
# 905                   3                3                      0
# 908                   3                3                      0
# 923                   3                3                      0
# ...                 ...              ...                    ...
# 26473                51               51                      0
# 26618                51               51                      1
# 27535                52               52                      2
# 27982                 1                1                      0
# 27990                 1                1                      0
#
#        PhySeenTime_hour
# 148                  12
# 573                  12
# 905                  11
# 908                  12
# 923                  13
# ...                 ...
# 26473                14
# 26618                12
# 27535                15
# 27982                14
# 27990                14
#
# [262 rows x 31 columns]

# %%
# Check the long waiting time dataset (WaitingTime >133)
df_LongWaitingTime.groupby('Facility')['WaitingTime'].describe()

# There are 274 out of 27146 appointments(1%) in facility 1 that has longer than 134 minutes waiting time.
# There are 8 out of 1056 appointments(0.76%) in facility 3 that has longer than 134 minutes waiting time.
# Out:
#             count        mean        std    min     25%    50%    75%    max
# Facility
# Facility_1  254.0  175.216535  45.348937  133.0  142.25  157.0  191.0  315.0
# Facility_3    8.0  198.875000  56.324157  136.0  157.25  182.5  241.5  285.0

# %%
# Check the long waiting time dataset: 

df_LongWaitingTime['Dept'].value_counts()

# Dermatology and medical departments expect longer waiting times.
# Out:
# Derma      141
# Medical     47
# Surg        33
# Gynae       18
# ANC         10
# Ortho        5
# Nephro       4
# Uro          2
# Psych        2
# Name: Dept, dtype: int64

# %%
df_LongWaitingTime['Appt_DateTime_month'].value_counts()
# Long waiting time appears most on July.
# Out:
# 7     38
# 10    31
# 4     30
# 9     28
# 2     27
# 1     25
# 8     22
# 3     21
# 6     18
# 5      8
# 11     7
# 12     7
# Name: Appt_DateTime_month, dtype: int64

# %%
df_LongWaitingTime['Appt_DateTime_dayofweek'].value_counts()
# Long waiting time appears more on Monday and Tuesday than any other day.
# Out:
# 0    63
# 1    55
# 3    53
# 6    50
# 2    41
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_LongWaitingTime['Appt_DateTime_hour'].value_counts()
# Long waiting time appears most at 10 am - 11am.
# Out:
# 10    67
# 11    55
# 9     48
# 12    36
# 8     30
# 13    15
# 14    11
# Name: Appt_DateTime_hour, dtype: int64

# %% [markdown]
# ## Facility

# %%
facility = df['Facility'].value_counts()
plt.figure(figsize=(5,5))
ax = sns.barplot(x=facility.index, y=facility.values, alpha=0.8) 
ax.bar_label(ax.containers[0])
plt.title('Facility')
# Out:
# Text(0.5, 1.0, 'Facility')

# %% [markdown]
# ## Dept
# * Dermatology has the most number of patients, while neurology has the least number of patients.

# %%
dept = df['Dept'].value_counts()

plt.figure(figsize=(10,8))
ax = sns.barplot(x=dept.index,y=dept.values,alpha=0.8) 
ax.bar_label(ax.containers[0])

plt.title('Department')
plt.ylabel('Number of patients',fontsize=12)
plt.xlabel('Department',fontsize=12)
plt.show()

# %% [markdown]
# ### Dermatology:
# - October, November and December are the busiest months for dermatology department.
# - There is no significant difference in the number of appointments among days of the week.
# - 8am - 11am are the busiest period. The number of appointments decrease significantly afre 12 pm.
# - 2pm is the busiest hour in the afternoon.

# %%
df_Derma=df.loc[(df['Dept'] =='Derma')]
df_Derma['Appt_DateTime_month'].value_counts()
# Out:
# 2     563
# 11    551
# 10    502
# 7     459
# 9     448
# 3     431
# 12    415
# 1     412
# 4     392
# 8     341
# 5     285
# 6     244
# Name: Appt_DateTime_month, dtype: int64

# %%
df_Derma['Appt_DateTime_dayofweek'].value_counts()
# Out:
# 1    1068
# 0    1050
# 6    1035
# 2     953
# 3     937
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_Derma['Appt_DateTime_hour'].value_counts()
# Out:
# 8     926
# 9     869
# 10    855
# 11    816
# 12    678
# 14    459
# 13    428
# 15     12
# Name: Appt_DateTime_hour, dtype: int64

# %% [markdown]
# ### Orthopedics
# - October and November are busy months for orthopedics department.
# - Monday and Wednesday are the busiest days of the week for orthopedics department.
# - 8am is the busiest hour of the day. 1pm is the busiest hour in the afternoon.

# %%
df_Ortho=df.loc[(df['Dept'] =='Ortho')]
df_Ortho['Appt_DateTime_month'].value_counts()
# Out:
# 10    635
# 11    567
# 12    492
# 1     431
# 9     417
# 3     397
# 2     371
# 4     367
# 5     278
# 8     252
# 7     237
# 6     232
# Name: Appt_DateTime_month, dtype: int64

# %%
df_Ortho=df.loc[(df['Dept'] =='Ortho')]
df_Ortho['Appt_DateTime_dayofweek'].value_counts()
# Out:
# 0    1094
# 2    1063
# 3     940
# 6     812
# 1     767
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_Ortho=df.loc[(df['Dept'] =='Ortho')]
df_Ortho['Appt_DateTime_hour'].value_counts()
# Out:
# 8     923
# 9     814
# 10    787
# 11    715
# 13    679
# 14    382
# 12    373
# 15      3
# Name: Appt_DateTime_hour, dtype: int64

# %% [markdown]
# ### Medical
# - October and December are the two busiest months for medical department.
# - Thursday is the businest day of the week.
# - 9am - 1pm is the busiest time period.
# - The number of patients start to increase from 9 am and start to decrease after 1pm.

# %%
df_Medical=df.loc[(df['Dept'] =='Medical')]
df_Medical['Appt_DateTime_month'].value_counts()
# Out:
# 12    521
# 10    511
# 11    484
# 9     351
# 1     347
# 2     279
# 4     248
# 7     246
# 3     245
# 6     204
# 8     202
# 5     172
# Name: Appt_DateTime_month, dtype: int64

# %%
df_Medical=df.loc[(df['Dept'] =='Medical')]
df_Medical['Appt_DateTime_dayofweek'].value_counts()
# Out:
# 3    929
# 2    830
# 6    796
# 0    780
# 1    475
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_Medical=df.loc[(df['Dept'] =='Medical')]
df_Medical['Appt_DateTime_hour'].value_counts()
# Out:
# 9     663
# 10    617
# 11    592
# 12    588
# 13    563
# 8     398
# 14    374
# 15     14
# 7       1
# Name: Appt_DateTime_hour, dtype: int64

# %% [markdown]
# ### Opthal
# - November is the busiest month for opthal department.
# - Tuesday, Thursday and Sunday are the three busiest days of the week. While the number of appointments are much fewer on Monday and Wednesday than any other days.
# - 8am is the busiest hour. The number of appoints gradually declines from 8am.
# - 1pm is the busiest hour in the afternoon.

# %%
df_Opthal =df.loc[(df['Dept'] =='Opthal')]
df_Opthal['Appt_DateTime_month'].value_counts()
# Out:
# 11    337
# 12    294
# 10    287
# 9     283
# 3     265
# 1     248
# 4     209
# 8     190
# 2     184
# 7     139
# 6     113
# 5     106
# Name: Appt_DateTime_month, dtype: int64

# %%
df_Opthal['Appt_DateTime_dayofweek'].value_counts()
# Out:
# 1    786
# 3    739
# 6    720
# 2    275
# 0    135
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_Opthal['Appt_DateTime_hour'].value_counts()
# Out:
# 8     607
# 9     477
# 10    472
# 11    405
# 13    284
# 14    238
# 12    162
# 7       6
# 15      4
# Name: Appt_DateTime_hour, dtype: int64

# %% [markdown]
# ### Gynaecology department
# - December is the busiest month for Gynaecology department.
# - Monday has the largest number of appointments, while Sunday has the least number of appointments.
# - 9am is the busiest hour of the whole day, and 1pm is the busiest hour in the afternoon.

# %%
df_Gynae =df.loc[(df['Dept'] =='Gynae')]
df_Gynae['Appt_DateTime_month'].value_counts()
# Out:
# 12    469
# 11    370
# 10    291
# 9     207
# 3     205
# 2     204
# 1     197
# 7     183
# 4     163
# 8     140
# 5     111
# 6     100
# Name: Appt_DateTime_month, dtype: int64

# %%
df_Gynae['Appt_DateTime_dayofweek'].value_counts()
# Out:
# 0    890
# 2    708
# 3    382
# 1    344
# 6    316
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_Gynae['Appt_DateTime_hour'].value_counts()
# Out:
# 9     451
# 11    439
# 8     429
# 10    406
# 13    381
# 12    301
# 14    231
# 15      2
# Name: Appt_DateTime_hour, dtype: int64

# %% [markdown]
# ### Antenatal care
# - March, January and February are the three busiest months for Antenatal care department. While May has the least number of appointments.
# - Thursday, Sunday and Monday are the three busiest days of the week, while Monday has the least number of patients.
# - 8am is the busiest hour of the whole day. 1pm is the busiest hour in the afternoon.

# %%
df_ANC =df.loc[(df['Dept'] =='ANC')]
df_ANC['Appt_DateTime_month'].value_counts()
# Out:
# 3     272
# 1     264
# 2     260
# 11    249
# 10    232
# 7     229
# 9     221
# 12    193
# 4     182
# 8     182
# 6     170
# 5     153
# Name: Appt_DateTime_month, dtype: int64

# %%
df_ANC['Appt_DateTime_dayofweek'].value_counts()
# Out:
# 3    793
# 6    701
# 1    690
# 2    239
# 0    184
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_ANC['Appt_DateTime_hour'].value_counts()
# Out:
# 8     511
# 9     442
# 10    403
# 11    385
# 13    353
# 12    309
# 14    201
# 15      3
# Name: Appt_DateTime_hour, dtype: int64

# %% [markdown]
# ### Surgeon
# - October is the busiest month for surgeon department. November and December are all very busy months.
# - Monday and Wednesday are the two busiest days of the week, while Thursday has the least number of patients.
# - 9am and 10am are the two busiest hours of the day.

# %%
df_Surg =df.loc[(df['Dept'] =='Surg')]
df_Surg['Appt_DateTime_month'].value_counts()
# Out:
# 10    300
# 11    226
# 12    224
# 9     195
# 4     157
# 1     151
# 3     151
# 7     135
# 8     125
# 5     122
# 2     109
# 6      90
# Name: Appt_DateTime_month, dtype: int64

# %%
df_Surg['Appt_DateTime_dayofweek'].value_counts()
# Out:
# 0    616
# 2    517
# 1    376
# 6    295
# 3    181
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_Surg['Appt_DateTime_hour'].value_counts()
# Out:
# 9     449
# 10    419
# 11    336
# 12    272
# 13    200
# 8     171
# 14    134
# 15      4
# Name: Appt_DateTime_hour, dtype: int64

# %% [markdown]
# ### Pediatric
# - October, December and November are the two busiest months for Pediatric department.
# - Tuesday is the busiest day of the week, while Sunday has the least number of patients.
# - 10am is the busiest hour of the day. 1pm is the busiest hour in the afternoon.

# %%
df_Paed =df.loc[(df['Dept'] =='Paed')]
df_Paed['Appt_DateTime_month'].value_counts()
# Out:
# 10    196
# 12    177
# 11    151
# 9     112
# 3     111
# 2     108
# 1      91
# 4      85
# 7      81
# 6      73
# 5      67
# 8      56
# Name: Appt_DateTime_month, dtype: int64

# %%
df_Paed['Appt_DateTime_dayofweek'].value_counts()
# Out:
# 1    372
# 0    266
# 3    258
# 2    226
# 6    186
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_Paed['Appt_DateTime_hour'].value_counts()
# Out:
# 10    310
# 9     276
# 11    250
# 12    212
# 13    166
# 14     76
# 8      15
# 15      3
# Name: Appt_DateTime_hour, dtype: int64

# %% [markdown]
# ### ENT(General Ear, Nose and Throat)
# - October, December and November are the three busiest months for ENT department.
# - Tuesday,Thursday and Sunday are the three busiest days of the week, while Monday and Wednesday have much less number of patients.
# - 9am is the busiest hour of all day. 2pm is the busiest hour in the afternoon.

# %%
df_ENT =df.loc[(df['Dept'] =='ENT')]
df_ENT['Appt_DateTime_month'].value_counts()
# Out:
# 10    210
# 12    188
# 11    184
# 3     124
# 4      92
# 1      85
# 5      82
# 2      73
# 9      72
# 8      62
# 7      61
# 6      52
# Name: Appt_DateTime_month, dtype: int64

# %%
df_ENT['Appt_DateTime_dayofweek'].value_counts()
# Out:
# 1    437
# 3    404
# 6    377
# 2     34
# 0     33
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_ENT['Appt_DateTime_hour'].value_counts()
# Out:
# 9     241
# 11    212
# 8     210
# 10    193
# 12    169
# 14    146
# 13    111
# 15      2
# 7       1
# Name: Appt_DateTime_hour, dtype: int64

# %% [markdown]
# ### Psychology
# - October, December and November are the two busiest months for Psychology department.
# - Thursday is the busiest day of the week, while Tuesday has the least number of patients.
# - There is not big difference in the number of appointments among the days of the week.
# - 9am is the busiest hour of the day. The number of appointments decline significantly after 12pm.

# %%
df_Psych =df.loc[(df['Dept'] =='Psych')]
df_Psych['Appt_DateTime_month'].value_counts()
# Out:
# 11    125
# 12     97
# 10     92
# 1      69
# 7      60
# 9      60
# 3      55
# 2      49
# 6      48
# 4      47
# 5      42
# 8      42
# Name: Appt_DateTime_month, dtype: int64

# %%
df_Psych['Appt_DateTime_dayofweek'].value_counts()
# Out:
# 3    188
# 2    173
# 6    154
# 0    145
# 1    126
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_Psych['Appt_DateTime_hour'].value_counts()
# Out:
# 9     184
# 10    168
# 8     134
# 11    126
# 12     98
# 13     49
# 14     27
# Name: Appt_DateTime_hour, dtype: int64

# %% [markdown]
# ### urology
# - October, December and November are the two busiest months for urology department. N
# - Tuesday,Sunday and Wednesday are the three busiest days of the week, while Monday and Wednesday have much less number of patients.
# - 10 am is the busiest hour of the day. The number of appointments decline significantly after 11am.

# %%
df_Uro =df.loc[(df['Dept'] =='Uro')]
df_Uro['Appt_DateTime_month'].value_counts()
# Out:
# 10    113
# 11     98
# 12     70
# 1      62
# 7      57
# 9      50
# 2      49
# 8      49
# 3      43
# 4      35
# 6      35
# 5      25
# Name: Appt_DateTime_month, dtype: int64

# %%
df_Uro =df.loc[(df['Dept'] =='Uro')]
df_Uro['Appt_DateTime_dayofweek'].value_counts()
# Out:
# 1    227
# 6    217
# 3    186
# 2     52
# 0      4
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_Uro =df.loc[(df['Dept'] =='Uro')]
df_Uro['Appt_DateTime_hour'].value_counts()
# Out:
# 10    168
# 11    147
# 9     135
# 12     93
# 14     62
# 13     58
# 8      23
# Name: Appt_DateTime_hour, dtype: int64

# %% [markdown]
# ### Nephrology
# - December, October and November are the three busiest months for Nephrology department.
# - May is the least busy month for Nephrology department.
# - Monday and Tuesday are the busiest day of the week. Wednesday and Sundayay have much less number of appointments.
# - There is no appointment on Thursday.
# - All appointments are on Monday, Tuesday and Wednesday except that one appointment is on Sunday.
# - 9am and 10 am are the busiest hours of the day.

# %%
df_Nephro =df.loc[(df['Dept'] =='Nephro')]
df_Nephro['Appt_DateTime_month'].value_counts()
# Out:
# 12    45
# 11    43
# 10    42
# 9     40
# 4     35
# 7     27
# 3     26
# 1     23
# 6     21
# 2     19
# 8     17
# 5     13
# Name: Appt_DateTime_month, dtype: int64

# %%
df_Nephro =df.loc[(df['Dept'] =='Nephro')]
df_Nephro['Appt_DateTime_dayofweek'].value_counts()
# Out:
# 1    177
# 0    162
# 2     11
# 6      1
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_Nephro =df.loc[(df['Dept'] =='Nephro')]
df_Nephro['Appt_DateTime_hour'].value_counts()
# Out:
# 9     123
# 10    114
# 11     71
# 12     31
# 8       9
# 13      3
# Name: Appt_DateTime_hour, dtype: int64

# %% [markdown]
# ### Neurology
# - November, July and September are the three busiest months for Neurology department.
# - June has the least number of patients.
# - Sunday is the busiest day of the week, while Thursday has the least number of patients.
# - 9am is the busiest hour of the day. 1pm is the busiest hour in the afternoon.

# %%
df_Neuro =df.loc[(df['Dept'] =='Neuro')]
df_Neuro['Appt_DateTime_month'].value_counts()
# Out:
# 11    39
# 7     35
# 9     35
# 3     32
# 1     27
# 2     27
# 10    27
# 12    23
# 4     21
# 5     21
# 8     21
# 6     13
# Name: Appt_DateTime_month, dtype: int64

# %%
df_Neuro =df.loc[(df['Dept'] =='Neuro')]
df_Neuro['Appt_DateTime_dayofweek'].value_counts()
# Out:
# 6    107
# 1     97
# 0     86
# 2     17
# 3     14
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_Neuro =df.loc[(df['Dept'] =='Neuro')]
df_Neuro['Appt_DateTime_hour'].value_counts()
# Out:
# 9     80
# 10    71
# 11    51
# 12    47
# 13    34
# 14    26
# 8     12
# Name: Appt_DateTime_hour, dtype: int64

# %% [markdown]
# ### Check if department has an effect on the waiting time

# %%
df.groupby('Dept')['WaitingTime'].describe()

# The dermatology department has the largest number of patients and the longest mean waiting time, 44.59 minutes. 
# The orthopedics department has the second largest number of patients but the second least mean waiting time, which is 18.29 minutes.
# Out:
#           count       mean        std  min   25%   50%    75%    max
# Dept
# ANC      2607.0  37.610280  25.084049  1.0  19.0  32.0  50.00  299.0
# Derma    5043.0  43.644854  37.643611  0.0  16.0  33.0  61.00  315.0
# ENT      1285.0  11.473152   9.992066  0.0   5.0   8.0  15.00  107.0
# Gynae    2640.0  35.684470  26.261966  0.0  16.0  29.0  48.00  252.0
# Medical  3810.0  35.482152  29.735640  0.0  14.0  29.0  49.00  313.0
# Nephro    351.0  32.005698  29.541157  2.0  14.0  25.0  41.00  273.0
# Neuro     321.0  19.056075  16.601674  1.0   6.0  14.0  28.00  119.0
# Opthal   2655.0  22.929190  17.018527  0.0  11.0  19.0  30.00  131.0
# Ortho    4676.0  18.042130  17.237856  0.0   6.0  13.0  24.00  256.0
# Paed     1308.0  25.734709  17.059618  1.0  13.0  22.0  34.00  110.0
# Psych     786.0  24.267176  20.039130  2.0  10.0  19.0  32.75  163.0
# Surg     1985.0  27.247355  29.062741  0.0   9.0  18.0  35.00  248.0
# Uro       686.0  23.602041  21.764109  0.0   9.0  17.0  31.00  235.0

# %%
# Check extreme waiting time dataset by department
df_ExtremeWaitingTime.groupby('Dept')['WaitingTime'].describe()

# Dermatology department has 13 appointments whose waiting time exceed 317 minutes. 
# Medical department has 5 appointments whose waiting time exceed 317 minutes. 
# Surgeon department has 3 appointments whose waiting time exceed 317 minutes.
# Out:
#          count        mean        std    min    25%    50%    75%    max
# Dept
# Derma     15.0  362.066667  49.186913  317.0  327.5  343.0  377.5  493.0
# Gynae      1.0  434.000000        NaN  434.0  434.0  434.0  434.0  434.0
# Medical    5.0  361.800000  46.986168  317.0  329.0  338.0  408.0  417.0
# Nephro     1.0  426.000000        NaN  426.0  426.0  426.0  426.0  426.0
# Ortho      3.0  398.000000  78.236820  329.0  355.5  382.0  432.5  483.0
# Psych      1.0  322.000000        NaN  322.0  322.0  322.0  322.0  322.0
# Surg       3.0  333.666667   1.154701  333.0  333.0  333.0  334.0  335.0

# %% [markdown]
# #### Dermatology: Extreme Waiting Time values

# %%
df_ExtremeWaitingTime.loc[(df_ExtremeWaitingTime['Dept'] =='Derma')]
# Out:
#              ID    Facility   Dept       Appt_DateTime          ChkIn_Time  \
# 4204   29440316  Facility_1  Derma 2019-02-24 12:50:00 2019-02-24 08:57:33
# 5573   31310736  Facility_1  Derma 2019-03-12 12:30:00 2019-03-12 07:59:34
# 5607   31014853  Facility_1  Derma 2019-03-12 12:00:00 2019-03-12 08:21:12
# 7538   32204900  Facility_1  Derma 2019-04-08 09:20:00 2019-04-08 09:12:37
# 7629   31951541  Facility_1  Derma 2019-04-09 12:50:00 2019-04-09 10:50:03
# 10059  33119763  Facility_1  Derma 2019-05-19 10:31:00 2019-05-19 08:22:59
# 11245  33258757  Facility_1  Derma 2019-06-18 09:13:00 2019-06-18 09:07:10
# 12053  33644521  Facility_1  Derma 2019-07-01 12:00:00 2019-07-01 09:00:22
# 12410  30785061  Facility_1  Derma 2019-07-07 09:16:00 2019-07-07 09:17:18
# 12558  33943864  Facility_1  Derma 2019-07-09 13:45:00 2019-07-09 08:54:58
# 12560  33943483  Facility_1  Derma 2019-07-09 13:21:00 2019-07-09 08:55:41
# 12963  33025639  Facility_1  Derma 2019-07-16 08:52:00 2019-07-16 09:02:09
# 13043  30680814  Facility_1  Derma 2019-07-17 09:40:00 2019-07-17 09:53:35
# 13044  31015795  Facility_1  Derma 2019-07-17 10:00:00 2019-07-17 09:55:21
# 14334  31899254  Facility_1  Derma 2019-08-06 09:20:00 2019-08-06 09:35:30
#
#               PhySeenTime Include  ChkIn_NurSeen  NurSeen_PhySeen  \
# 4204  2019-02-24 15:19:04     Yes             24              358
# 5573  2019-03-12 13:26:20     Yes              5              322
# 5607  2019-03-12 16:34:49     Yes             24              469
# 7538  2019-04-08 15:13:10     Yes             26              335
# 7629  2019-04-09 16:07:34     Yes              2              315
# 10059 2019-05-19 14:08:55     Yes              0                0
# 11245 2019-06-18 14:24:57     Yes            150              167
# 12053 2019-07-01 14:22:39     Yes              8              314
# 12410 2019-07-07 16:05:47     Yes             17              391
# 12558 2019-07-09 14:37:45     Yes            345               -2
# 12560 2019-07-09 16:05:07     Yes             14              416
# 12963 2019-07-16 15:15:05     Yes             17              356
# 13043 2019-07-17 15:35:25     Yes              8              334
# 13044 2019-07-17 15:37:45     Yes              9              333
# 14334 2019-08-06 15:03:31     Yes             62              266
#
#        WaitingTime  ...  ChkIn_Time_month  ChkIn_Time_week  ChkIn_Time_day  \
# 4204           382  ...                 2                8               8
# 5573           327  ...                 3               11              11
# 5607           493  ...                 3               11              11
# 7538           361  ...                 4               15              15
# 7629           317  ...                 4               15              15
# 10059          346  ...                 5               20              20
# 11245          317  ...                 6               25              25
# 12053          322  ...                 7               27              27
# 12410          408  ...                 7               27              27
# 12558          343  ...                 7               28              28
# 12560          430  ...                 7               28              28
# 12963          373  ...                 7               29              29
# 13043          342  ...                 7               29              29
# 13044          342  ...                 7               29              29
# 14334          328  ...                 8               32              32
#
#       ChkIn_Time_dayofweek ChkIn_Time_hour  PhySeenTime_month  \
# 4204                     6               8                  2
# 5573                     1               7                  3
# 5607                     1               8                  3
# 7538                     0               9                  4
# 7629                     1              10                  4
# 10059                    6               8                  5
# 11245                    1               9                  6
# 12053                    0               9                  7
# 12410                    6               9                  7
# 12558                    1               8                  7
# 12560                    1               8                  7
# 12963                    1               9                  7
# 13043                    2               9                  7
# 13044                    2               9                  7
# 14334                    1               9                  8
#
#        PhySeenTime_week  PhySeenTime_day  PhySeenTime_dayofweek  \
# 4204                  8                8                      6
# 5573                 11               11                      1
# 5607                 11               11                      1
# 7538                 15               15                      0
# 7629                 15               15                      1
# 10059                20               20                      6
# 11245                25               25                      1
# 12053                27               27                      0
# 12410                27               27                      6
# 12558                28               28                      1
# 12560                28               28                      1
# 12963                29               29                      1
# 13043                29               29                      2
# 13044                29               29                      2
# 14334                32               32                      1
#
#        PhySeenTime_hour
# 4204                 15
# 5573                 13
# 5607                 16
# 7538                 15
# 7629                 16
# 10059                14
# 11245                14
# 12053                14
# 12410                16
# 12558                14
# 12560                16
# 12963                15
# 13043                15
# 13044                15
# 14334                15
#
# [15 rows x 31 columns]

# %%
df_ExtremeWaitingTime.loc[(df_ExtremeWaitingTime['Dept'] =='Derma')]['Phy_Name'].value_counts()
# Out:
# Doc43     12
# Doc50      2
# Doc133     1
# Name: Phy_Name, dtype: int64

# %%
# Among 13 rows, 6 of them check in hours earlier than their appointment times. So, the waiting time may not reflect the actual waiting time of the patients. 
# 4 of them check in after their appointment time. 
# 10 appointments fall into Doc43, 2 appointments under Doc50 and 1 under Doc 133.

# %% [markdown]
# #### Medical: Extreme Waiting Time values

# %%
df_ExtremeWaitingTime.loc[(df_ExtremeWaitingTime['Dept'] =='Medical')]

display(df_ExtremeWaitingTime.loc[(df_ExtremeWaitingTime['Dept'] =='Medical')].head().T)

# Among 5 appointments, 1 of them check in hours earilier than its appointment time. So, the waiting time may not reflect the actual waiting time of the patients. 
# 2 of them check in after their appointment time. 
# 4 of appointments falls into Doctor 144 and one was with Doc78.
# Out:
#                                        84                   840    \
# ID                                  30130229             29233382
# Facility                          Facility_1           Facility_1
# Dept                                 Medical              Medical
# Appt_DateTime            2019-01-02 09:55:00  2019-01-13 08:50:00
# ChkIn_Time               2019-01-02 09:56:44  2019-01-13 08:22:59
# PhySeenTime              2019-01-02 15:13:34  2019-01-13 15:19:04
# Include                                  Yes                  Yes
# ChkIn_NurSeen                             20                   24
# NurSeen_PhySeen                          297                  393
# WaitingTime                              317                  417
# PhySeen_ChkOut                             9                    2
# ChkIn_ChkOut                             326                  419
# Duration                                  20                   30
# Phy_Name                              Doc144               Doc144
# Appt_Date                         2019-01-02           2019-01-13
# Appt_Count                                 9                    9
# Appt_DateTime_month                        1                    1
# Appt_DateTime_week                         1                    2
# Appt_DateTime_day                          1                    2
# Appt_DateTime_dayofweek                    2                    6
# Appt_DateTime_hour                         9                    8
# ChkIn_Time_month                           1                    1
# ChkIn_Time_week                            1                    2
# ChkIn_Time_day                             1                    2
# ChkIn_Time_dayofweek                       2                    6
# ChkIn_Time_hour                            9                    8
# PhySeenTime_month                          1                    1
# PhySeenTime_week                           1                    2
# PhySeenTime_day                            1                    2
# PhySeenTime_dayofweek                      2                    6
# PhySeenTime_hour                          15                   15
#
#                                        5356                 12551  \
# ID                                  31784141             34091079
# Facility                          Facility_1           Facility_1
# Dept                                 Medical              Medical
# Appt_DateTime            2019-03-10 08:40:00  2019-07-09 12:40:00
# ChkIn_Time               2019-03-10 08:45:30  2019-07-09 08:28:37
# PhySeenTime              2019-03-10 14:23:49  2019-07-09 13:57:22
# Include                                  Yes                  Yes
# ChkIn_NurSeen                             12                    0
# NurSeen_PhySeen                          326                    0
# WaitingTime                              338                  329
# PhySeen_ChkOut                            30                    1
# ChkIn_ChkOut                             368                  330
# Duration                                  20                   20
# Phy_Name                              Doc144                Doc78
# Appt_Date                         2019-03-10           2019-07-09
# Appt_Count                                 9                    3
# Appt_DateTime_month                        3                    7
# Appt_DateTime_week                        10                   28
# Appt_DateTime_day                         10                   28
# Appt_DateTime_dayofweek                    6                    1
# Appt_DateTime_hour                         8                   12
# ChkIn_Time_month                           3                    7
# ChkIn_Time_week                           10                   28
# ChkIn_Time_day                            10                   28
# ChkIn_Time_dayofweek                       6                    1
# ChkIn_Time_hour                            8                    8
# PhySeenTime_month                          3                    7
# PhySeenTime_week                          10                   28
# PhySeenTime_day                           10                   28
# PhySeenTime_dayofweek                      6                    1
# PhySeenTime_hour                          14                   13
#
#                                        17825
# ID                                  35257124
# Facility                          Facility_1
# Dept                                 Medical
# Appt_DateTime            2019-09-26 08:30:00
# ChkIn_Time               2019-09-26 08:16:18
# PhySeenTime              2019-09-26 15:04:39
# Include                                  Yes
# ChkIn_NurSeen                             30
# NurSeen_PhySeen                          378
# WaitingTime                              408
# PhySeen_ChkOut                             9
# ChkIn_ChkOut                             417
# Duration                                  30
# Phy_Name                              Doc144
# Appt_Date                         2019-09-26
# Appt_Count                                11
# Appt_DateTime_month                        9
# Appt_DateTime_week                        39
# Appt_DateTime_day                         39
# Appt_DateTime_dayofweek                    3
# Appt_DateTime_hour                         8
# ChkIn_Time_month                           9
# ChkIn_Time_week                           39
# ChkIn_Time_day                            39
# ChkIn_Time_dayofweek                       3
# ChkIn_Time_hour                            8
# PhySeenTime_month                          9
# PhySeenTime_week                          39
# PhySeenTime_day                           39
# PhySeenTime_dayofweek                      3
# PhySeenTime_hour                          15

# %% [markdown]
# #### Surgeon: Extreme Waiting Time values

# %%
display(df_ExtremeWaitingTime.loc[(df_ExtremeWaitingTime['Dept'] =='Surg')].head().T)
# Out:
#                                        494                  10232  \
# ID                                  30681308             33178634
# Facility                          Facility_1           Facility_1
# Dept                                    Surg                 Surg
# Appt_DateTime            2019-01-08 08:00:00  2019-05-22 08:00:00
# ChkIn_Time               2019-01-08 07:49:23  2019-05-22 08:12:37
# PhySeenTime              2019-01-08 13:24:06  2019-05-22 13:45:36
# Include                                  Yes                  Yes
# ChkIn_NurSeen                              0                   15
# NurSeen_PhySeen                          335                  318
# WaitingTime                              335                  333
# PhySeen_ChkOut                             0                    0
# ChkIn_ChkOut                             335                  333
# Duration                                  30                   20
# Phy_Name                              Doc148                Doc63
# Appt_Date                         2019-01-08           2019-05-22
# Appt_Count                                 1                    1
# Appt_DateTime_month                        1                    5
# Appt_DateTime_week                         2                   21
# Appt_DateTime_day                          2                   21
# Appt_DateTime_dayofweek                    1                    2
# Appt_DateTime_hour                         8                    8
# ChkIn_Time_month                           1                    5
# ChkIn_Time_week                            2                   21
# ChkIn_Time_day                             2                   21
# ChkIn_Time_dayofweek                       1                    2
# ChkIn_Time_hour                            7                    8
# PhySeenTime_month                          1                    5
# PhySeenTime_week                           2                   21
# PhySeenTime_day                            2                   21
# PhySeenTime_dayofweek                      1                    2
# PhySeenTime_hour                          13                   13
#
#                                        23879
# ID                                  35880467
# Facility                          Facility_1
# Dept                                    Surg
# Appt_DateTime            2019-11-19 08:00:00
# ChkIn_Time               2019-11-19 07:57:00
# PhySeenTime              2019-11-19 13:30:50
# Include                                  Yes
# ChkIn_NurSeen                             17
# NurSeen_PhySeen                          316
# WaitingTime                              333
# PhySeen_ChkOut                             0
# ChkIn_ChkOut                               0
# Duration                                  20
# Phy_Name                              Doc148
# Appt_Date                         2019-11-19
# Appt_Count                                 1
# Appt_DateTime_month                       11
# Appt_DateTime_week                        47
# Appt_DateTime_day                         47
# Appt_DateTime_dayofweek                    1
# Appt_DateTime_hour                         8
# ChkIn_Time_month                          11
# ChkIn_Time_week                           47
# ChkIn_Time_day                            47
# ChkIn_Time_dayofweek                       1
# ChkIn_Time_hour                            7
# PhySeenTime_month                         11
# PhySeenTime_week                          47
# PhySeenTime_day                           47
# PhySeenTime_dayofweek                      1
# PhySeenTime_hour                          13

# %%
# Among 3 rows, all of them check in a few minutes before their appointment time. 
# 2 of them falls into Doctor 148 and one was with Doc63.

# %% [markdown]
# #### Ortho: Extreme Waiting Time values

# %%
display(df_ExtremeWaitingTime.loc[(df_ExtremeWaitingTime['Dept'] =='Ortho')].head().T)
# Out:
#                                        4295                 12654  \
# ID                                  31432050             34039721
# Facility                          Facility_1           Facility_1
# Dept                                   Ortho                Ortho
# Appt_DateTime            2019-02-25 08:00:00  2019-07-10 08:10:00
# ChkIn_Time               2019-02-25 08:12:47  2019-07-10 08:14:09
# PhySeenTime              2019-02-25 13:41:59  2019-07-10 14:36:24
# Include                                  Yes                  Yes
# ChkIn_NurSeen                             22                    0
# NurSeen_PhySeen                          307                    0
# WaitingTime                              329                  382
# PhySeen_ChkOut                             1                    0
# ChkIn_ChkOut                             330                  382
# Duration                                  20                   20
# Phy_Name                               Doc58                 Doc7
# Appt_Date                         2019-02-25           2019-07-10
# Appt_Count                                 5                    8
# Appt_DateTime_month                        2                    7
# Appt_DateTime_week                         9                   28
# Appt_DateTime_day                          9                   28
# Appt_DateTime_dayofweek                    0                    2
# Appt_DateTime_hour                         8                    8
# ChkIn_Time_month                           2                    7
# ChkIn_Time_week                            9                   28
# ChkIn_Time_day                             9                   28
# ChkIn_Time_dayofweek                       0                    2
# ChkIn_Time_hour                            8                    8
# PhySeenTime_month                          2                    7
# PhySeenTime_week                           9                   28
# PhySeenTime_day                            9                   28
# PhySeenTime_dayofweek                      0                    2
# PhySeenTime_hour                          13                   14
#
#                                        21383
# ID                                  35975741
# Facility                          Facility_1
# Dept                                   Ortho
# Appt_DateTime            2019-10-30 08:30:00
# ChkIn_Time               2019-10-30 08:29:14
# PhySeenTime              2019-10-30 16:32:51
# Include                                  Yes
# ChkIn_NurSeen                             32
# NurSeen_PhySeen                          451
# WaitingTime                              483
# PhySeen_ChkOut                             5
# ChkIn_ChkOut                             488
# Duration                                  20
# Phy_Name                              Doc142
# Appt_Date                         2019-10-30
# Appt_Count                                13
# Appt_DateTime_month                       10
# Appt_DateTime_week                        44
# Appt_DateTime_day                         44
# Appt_DateTime_dayofweek                    2
# Appt_DateTime_hour                         8
# ChkIn_Time_month                          10
# ChkIn_Time_week                           44
# ChkIn_Time_day                            44
# ChkIn_Time_dayofweek                       2
# ChkIn_Time_hour                            8
# PhySeenTime_month                         10
# PhySeenTime_week                          44
# PhySeenTime_day                           44
# PhySeenTime_dayofweek                      2
# PhySeenTime_hour                          16

# %%
# All of them check in a few minutes after their appointment time. 
# 1 of them falls into Doctor 58 and one was with Doc7.

# %% [markdown]
# #### Nephro: Extreme Waiting Time values

# %%
display(df_ExtremeWaitingTime.loc[(df_ExtremeWaitingTime['Dept'] =='Nephro')].head().T)
# Out:
#                                        20561
# ID                                  36491812
# Facility                          Facility_1
# Dept                                  Nephro
# Appt_DateTime            2019-10-23 10:00:00
# ChkIn_Time               2019-10-23 10:14:08
# PhySeenTime              2019-10-23 17:20:46
# Include                                  Yes
# ChkIn_NurSeen                              0
# NurSeen_PhySeen                            0
# WaitingTime                              426
# PhySeen_ChkOut                            13
# ChkIn_ChkOut                             439
# Duration                                  20
# Phy_Name                              Doc106
# Appt_Date                         2019-10-23
# Appt_Count                                 1
# Appt_DateTime_month                       10
# Appt_DateTime_week                        43
# Appt_DateTime_day                         43
# Appt_DateTime_dayofweek                    2
# Appt_DateTime_hour                        10
# ChkIn_Time_month                          10
# ChkIn_Time_week                           43
# ChkIn_Time_day                            43
# ChkIn_Time_dayofweek                       2
# ChkIn_Time_hour                           10
# PhySeenTime_month                         10
# PhySeenTime_week                          43
# PhySeenTime_day                           43
# PhySeenTime_dayofweek                      2
# PhySeenTime_hour                          17

# %%
# The patient checks in a few minutes after their appointment time. 
# It falls into Doctor 106.

# %% [markdown]
# #### Psych: Extreme Waiting Time values

# %%
display(df_ExtremeWaitingTime.loc[(df_ExtremeWaitingTime['Dept'] =='Psych')].head().T)
# Out:
#                                        12951
# ID                                  34169207
# Facility                          Facility_1
# Dept                                   Psych
# Appt_DateTime            2019-07-16 11:40:00
# ChkIn_Time               2019-07-16 08:55:04
# PhySeenTime              2019-07-16 14:17:43
# Include                                  Yes
# ChkIn_NurSeen                             21
# NurSeen_PhySeen                          301
# WaitingTime                              322
# PhySeen_ChkOut                            19
# ChkIn_ChkOut                             341
# Duration                                  20
# Phy_Name                              Doc125
# Appt_Date                         2019-07-16
# Appt_Count                                 1
# Appt_DateTime_month                        7
# Appt_DateTime_week                        29
# Appt_DateTime_day                         29
# Appt_DateTime_dayofweek                    1
# Appt_DateTime_hour                        11
# ChkIn_Time_month                           7
# ChkIn_Time_week                           29
# ChkIn_Time_day                            29
# ChkIn_Time_dayofweek                       1
# ChkIn_Time_hour                            8
# PhySeenTime_month                          7
# PhySeenTime_week                          29
# PhySeenTime_day                           29
# PhySeenTime_dayofweek                      1
# PhySeenTime_hour                          14

# %%
# The patient checks in 2 hours 45 minutes before their appointment time. 
# It falls into Doctor 125.

# %% [markdown]
# ## ChkIn_NurSeen

# %%
df['ChkIn_NurSeen'].describe()
# Out:
# count    28153.000000
# mean         8.912940
# std         10.720598
# min        -61.000000
# 25%          2.000000
# 50%          6.000000
# 75%         12.000000
# max        231.000000
# Name: ChkIn_NurSeen, dtype: float64

# %%
df['ChkIn_NurSeen'].plot.hist(grid=True,bins=20,rwidth=0.9,color='#607c8e')
plt.title('ChkIn_NurSeen')
plt.xlabel('Counts')
plt.ylabel('ChkIn_NurSeen')
plt.grid(axis='y',alpha=0.75)

# %%
df['ChkIn_NurSeen'].quantile([0.0001,0.05,0.1,.2,0.75,0.90,0.95,0.97,0.98,0.99,.999])
# Out:
# 0.0001   -36.3264
# 0.0500     0.0000
# 0.1000     1.0000
# 0.2000     2.0000
# 0.7500    12.0000
# 0.9000    21.0000
# 0.9500    28.0000
# 0.9700    34.0000
# 0.9800    40.0000
# 0.9900    50.0000
# 0.9990    97.0000
# Name: ChkIn_NurSeen, dtype: float64

# %%
# Deal with the outliers:
df.loc[df['ChkIn_NurSeen']>99,'ChkIn_NurSeen']=99

## ChkIn_NurSeen time should not be below 0:
df.loc[df['ChkIn_NurSeen']<0,'ChkIn_NurSeen']=0

# %%
df['ChkIn_NurSeen'].plot.hist(grid=True,bins=20,rwidth=0.9,color='#607c8e')
plt.title('ChkIn_NurSeen')
plt.xlabel('Counts')
plt.ylabel('ChkIn_NurSeen')
plt.grid(axis='y',alpha=0.75)

# %% [markdown]
# ## NurSeen_PhySeen

# %%
df['NurSeen_PhySeen'].describe()
# Out:
# count    28153.000000
# mean        20.730153
# std         24.958997
# min        -52.000000
# 25%          4.000000
# 50%         12.000000
# 75%         29.000000
# max        312.000000
# Name: NurSeen_PhySeen, dtype: float64

# %%
df['NurSeen_PhySeen'].quantile([0.0001,0.02,0.1,.2,0.75,0.90,0.95,0.97,0.98,0.99,.999])
# Out:
# 0.0001    -21.7392
# 0.0200      0.0000
# 0.1000      1.0000
# 0.2000      3.0000
# 0.7500     29.0000
# 0.9000     51.0000
# 0.9500     68.0000
# 0.9700     80.0000
# 0.9800     91.0000
# 0.9900    111.4800
# 0.9990    225.0000
# Name: NurSeen_PhySeen, dtype: float64

# %%
# Replace the outliers:
df.loc[df['NurSeen_PhySeen']>287,'NurSeen_PhySeen']=287

# ChkIn_NurSeen should be at least 0. 
df.loc[df['NurSeen_PhySeen']<0,'NurSeen_PhySeen']=0

# %%
df['NurSeen_PhySeen'].plot.hist(grid=True,bins=20,rwidth=0.9,color='#607c8e')
plt.title('NurSeen_PhySeen')
plt.xlabel('Counts')
plt.ylabel('NurSeen_PhySeen')
plt.grid(axis='y',alpha=0.75)

# %% [markdown]
# ## PhySeen_ChkOut

# %%
df['PhySeen_ChkOut'].describe()
# Out:
# count    28153.000000
# mean        28.645580
# std         58.052286
# min          0.000000
# 25%         11.000000
# 50%         19.000000
# 75%         32.000000
# max       5414.000000
# Name: PhySeen_ChkOut, dtype: float64

# %%
df['PhySeen_ChkOut'].quantile([0.0001,0.1,.2,0.75,0.90,0.95,0.97,0.98,0.99,.999])
# Out:
# 0.0001      0.0
# 0.1000      6.0
# 0.2000      9.0
# 0.7500     32.0
# 0.9000     56.0
# 0.9500     81.0
# 0.9700    107.0
# 0.9800    132.0
# 0.9900    185.0
# 0.9990    370.0
# Name: PhySeen_ChkOut, dtype: float64

# %%
# deal with the outliers
df.loc[df['PhySeen_ChkOut']>370,'PhySeen_ChkOut']=370

# %%
df['PhySeen_ChkOut'].plot.hist(grid=True,bins=20,rwidth=0.9,color='#607c8e')
plt.title('PhySeen_ChkOut')
plt.xlabel('Counts')
plt.ylabel('PhySeen_ChkOut')
plt.grid(axis='y',alpha=0.75)

# %%
df.groupby('Dept')['PhySeen_ChkOut'].describe()

# Pshchology department has the longest physcian seen time. 
# ENT department had the shortest physcian seen time.
# Out:
#           count       mean        std  min   25%   50%    75%    max
# Dept
# ANC      2607.0  28.537399  28.019578  0.0  17.0  23.0  33.00  370.0
# Derma    5043.0  26.316478  31.163122  0.0  11.0  19.0  30.00  370.0
# ENT      1285.0  11.534630  12.501455  0.0   6.0   9.0  13.00  197.0
# Gynae    2640.0  31.266288  36.890413  0.0  15.0  24.0  36.00  370.0
# Medical  3810.0  25.583727  36.842764  0.0  10.0  16.0  25.00  370.0
# Nephro    351.0  18.356125  18.341092  0.0  10.0  15.0  23.00  172.0
# Neuro     321.0  19.579439  11.121239  0.0  12.0  18.0  25.00   71.0
# Opthal   2655.0  38.810546  39.376651  0.0  15.0  25.0  49.00  370.0
# Ortho    4676.0  31.114842  42.209945  0.0   9.0  16.0  39.00  370.0
# Paed     1308.0  22.391437  23.986409  0.0  11.0  18.0  28.00  354.0
# Psych     786.0  45.265903  38.147375  0.0  24.0  34.0  52.75  370.0
# Surg     1985.0  24.709824  29.936516  0.0  10.0  17.0  29.00  288.0
# Uro       686.0  16.899417  36.937826  0.0   4.0   8.0  14.00  370.0

# %% [markdown]
# ### PhySeen_ChkOut =0

# %%
# Check when PhySeen_ChkOut is 0, which means doctors do not see patients but still let the patients wait. 
df_NoPhySeen = df.loc[df['PhySeen_ChkOut'] ==0]

# %%
df_NoPhySeen['Phy_Name'].value_counts()

# Doc119 has 78 times of not seeing the patients.
# Out:
# Doc119    78
# Doc132    63
# Doc115    62
# Doc7      46
# Doc22     39
#           ..
# Doc37      1
# Doc122     1
# Doc59      1
# Doc34      1
# Doc67      1
# Name: Phy_Name, Length: 99, dtype: int64

# %%
df_NoPhySeen['Dept'].value_counts()

# Gynae department has 219 times of not seeing the patients.
# Out:
# Gynae      218
# Ortho      198
# Medical    168
# ANC        139
# Uro         97
# Surg        85
# Paed        74
# Derma       61
# ENT         37
# Nephro      36
# Opthal      24
# Psych        3
# Neuro        2
# Name: Dept, dtype: int64

# %%
df_NoPhySeen.groupby('Dept')['WaitingTime'].describe()

# Gynae department has the largest number of doctors not seeing patients. 
# Neuro department and psychology departments have the least number of doctors not seeing patients. 
# Surgical department has the patients wait the longest mean time.
# Out:
#          count       mean        std   min    25%   50%    75%    max
# Dept
# ANC      139.0  50.143885  34.901219   3.0  24.00  42.0  68.00  252.0
# Derma     61.0  52.852459  35.718266   9.0  28.00  45.0  63.00  164.0
# ENT       37.0  21.972973  12.822477   5.0  12.00  19.0  27.00   54.0
# Gynae    218.0  46.197248  34.207588   1.0  21.00  40.0  63.00  252.0
# Medical  168.0  55.386905  43.306584   5.0  27.00  43.5  72.50  280.0
# Nephro    36.0  53.000000  41.201248  15.0  30.50  42.0  62.50  226.0
# Neuro      2.0  31.500000   0.707107  31.0  31.25  31.5  31.75   32.0
# Opthal    24.0  26.750000  20.914422   2.0  14.75  20.0  33.00   82.0
# Ortho    198.0  28.035354  24.035375   1.0  14.25  22.0  33.00  253.0
# Paed      74.0  33.445946  15.953822   2.0  23.00  30.0  44.00   82.0
# Psych      3.0  40.333333  27.465129  23.0  24.50  26.0  49.00   72.0
# Surg      85.0  52.411765  50.775719   2.0  19.00  37.0  60.00  215.0
# Uro       97.0  27.917526  19.962293   4.0  15.00  22.0  35.00  115.0

# %%
df_NoPhySeen['Appt_DateTime_dayofweek'].value_counts()
# Tuesday has the largest number of doctors not seeing patients.
# Out:
# 1    274
# 3    243
# 2    234
# 0    215
# 6    176
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_NoPhySeen['Appt_DateTime_hour'].value_counts()

# In the morning, 9-11am is the period of not seeing the patients.
# In the afternoon, 1-2pm is the time period of not seeing the patients.
# The time period matches the busy hours.
# Out:
# 10    194
# 11    190
# 9     185
# 13    157
# 12    154
# 14    137
# 8     121
# 15      4
# Name: Appt_DateTime_hour, dtype: int64

# %% [markdown]
# ## ChkIn_ChkOut

# %%
# ChkIn_ChkOut is the sum of WaitingTime and PhySeen, so it should not exert any effect on the dependent variable: WaitingTime.

# %%
df['ChkIn_ChkOut'].describe()
# Out:
# count    28153.000000
# mean        58.086243
# std         63.986924
# min          0.000000
# 25%         30.000000
# 50%         47.000000
# 75%         72.000000
# max       5436.000000
# Name: ChkIn_ChkOut, dtype: float64

# %%
sns.histplot(df['ChkIn_ChkOut'])
# Out:
# <Axes: xlabel='ChkIn_ChkOut', ylabel='Count'>

# %% [markdown]
# ## Duration

# %%
df['Duration'].describe()
# Out:
# count    28153.000000
# mean        22.824743
# std          5.083968
# min          5.000000
# 25%         20.000000
# 50%         20.000000
# 75%         30.000000
# max         60.000000
# Name: Duration, dtype: float64

# %%
df['Duration'].value_counts()
# Out:
# 20    19288
# 30     7857
# 15      680
# 45      144
# 10       99
# 40       48
# 60       18
# 25       13
# 35        3
# 5         3
# Name: Duration, dtype: int64

# %%
sns.histplot(df['Duration'])
# Out:
# <Axes: xlabel='Duration', ylabel='Count'>

# %% [markdown]
# ## Phy_Name

# %%
df['Phy_Name'].value_counts()
# Out:
# Doc133    1844
# Doc50     1506
# Doc43     1166
# Doc2      1031
# Doc21      979
#           ...
# Doc139       5
# Doc57        5
# Doc59        3
# Doc122       2
# Doc91        1
# Name: Phy_Name, Length: 113, dtype: int64

# %%
df.groupby('Phy_Name')['WaitingTime'].mean().sort_values(ascending=False)
# Out:
# Phy_Name
# Doc84     162.222222
# Doc57      77.400000
# Doc43      65.382504
# Doc59      60.000000
# Doc122     56.500000
#              ...
# Doc37      13.561404
# Doc33      12.876923
# Doc3       11.696113
# Doc48      10.733813
# Doc9        9.810909
# Name: WaitingTime, Length: 113, dtype: float64

# %% [markdown]
# ### Check doctor 84

# %%
# We can see that Doc 84 has the longest mean WaitingTime, while Doc9 has the shortest mean WaitingTime. 

df.loc[df['Phy_Name'] =='Doc84']

# We can see Patients' waiting time are very long in 02/28/2019 and 07/18/2019.
# In 02/28/2019, the doctor saw the first patient 285 minutes later than its appointment time. It might be due to the doctor's unexpected situations.
# In 07/18/2019, the doctor saw the first patient 59 minutes later than its appointment time. The PhySeen_ChkOut is 19 minutes. It doesn't show any significant delay from the first patient.
# Out:
#              ID    Facility     Dept       Appt_DateTime          ChkIn_Time  \
# 4677   31612920  Facility_3  Medical 2019-02-28 09:50:00 2019-02-28 09:18:44
# 4678   31659028  Facility_3  Medical 2019-02-28 10:10:00 2019-02-28 09:37:56
# 4679   31652955  Facility_3  Medical 2019-02-28 10:30:00 2019-02-28 10:11:15
# 4681   31696249  Facility_3  Medical 2019-02-28 11:00:00 2019-02-28 11:06:37
# 13075  34159922  Facility_3  Medical 2019-07-18 09:00:00 2019-07-18 09:12:27
# 13089  34207239  Facility_3  Medical 2019-07-18 09:20:00 2019-07-18 09:23:33
# 13093  34269309  Facility_3  Medical 2019-07-18 09:40:00 2019-07-18 09:51:11
# 13101  34106363  Facility_3  Medical 2019-07-18 10:00:00 2019-07-18 10:06:27
# 13110  34276456  Facility_3  Medical 2019-07-18 10:40:00 2019-07-18 10:43:18
#
#               PhySeenTime Include  ChkIn_NurSeen  NurSeen_PhySeen  \
# 4677  2019-02-28 14:03:58     Yes              4              281
# 4678  2019-02-28 14:04:16     Yes             11              256
# 4679  2019-02-28 14:04:22     Yes              8              225
# 4681  2019-02-28 14:06:16     Yes             17              163
# 13075 2019-07-18 10:11:04     Yes              4               55
# 13089 2019-07-18 11:16:14     Yes              8              105
# 13093 2019-07-18 11:24:34     Yes              6               87
# 13101 2019-07-18 12:01:19     Yes              3              112
# 13110 2019-07-18 12:38:26     Yes             12              103
#
#        WaitingTime  ...  ChkIn_Time_month  ChkIn_Time_week  ChkIn_Time_day  \
# 4677           285  ...                 2                9               9
# 4678           267  ...                 2                9               9
# 4679           233  ...                 2                9               9
# 4681           180  ...                 2                9               9
# 13075           59  ...                 7               29              29
# 13089          113  ...                 7               29              29
# 13093           93  ...                 7               29              29
# 13101          115  ...                 7               29              29
# 13110          115  ...                 7               29              29
#
#       ChkIn_Time_dayofweek ChkIn_Time_hour  PhySeenTime_month  \
# 4677                     3               9                  2
# 4678                     3               9                  2
# 4679                     3              10                  2
# 4681                     3              11                  2
# 13075                    3               9                  7
# 13089                    3               9                  7
# 13093                    3               9                  7
# 13101                    3              10                  7
# 13110                    3              10                  7
#
#        PhySeenTime_week  PhySeenTime_day  PhySeenTime_dayofweek  \
# 4677                  9                9                      3
# 4678                  9                9                      3
# 4679                  9                9                      3
# 4681                  9                9                      3
# 13075                29               29                      3
# 13089                29               29                      3
# 13093                29               29                      3
# 13101                29               29                      3
# 13110                29               29                      3
#
#        PhySeenTime_hour
# 4677                 14
# 4678                 14
# 4679                 14
# 4681                 14
# 13075                10
# 13089                11
# 13093                11
# 13101                12
# 13110                12
#
# [9 rows x 31 columns]

# %% [markdown]
# ### Check doctor 57

# %%
df.loc[df['Phy_Name'] =='Doc57']

# We can see Patients' waiting time are very long in 01/17/2019, 04/23/2019 and 06/11/2019
# In 01/17/2019, the doctor saw the first patient 89 minutes later than its appointment time. It might be due to the doctor's unexpected situations. That further delays the following appointment.
# In 04/23/2019, the doctor saw the patient 72 minutes later than its appointment time. The PhySeen_ChkOut is 0 minutes. There is not sufficient data to see the reason behind it.
# In 06/11/2019, the doctor saw the patient 100 minutes later than its appointment time. The PhySeen_ChkOut is 0 minutes.There is not sufficient data to see the reason behind it.
# Out:
#              ID    Facility     Dept       Appt_DateTime          ChkIn_Time  \
# 1278   30798837  Facility_1  Medical 2019-01-17 12:00:00 2019-01-17 11:52:30
# 1281   30798723  Facility_1  Medical 2019-01-17 12:10:00 2019-01-17 11:51:15
# 6130   32032347  Facility_1  Medical 2019-03-19 12:00:00 2019-03-19 11:46:44
# 8587   31024929  Facility_1  Medical 2019-04-23 13:00:00 2019-04-23 13:07:00
# 10771  33123571  Facility_1  Medical 2019-06-11 12:00:00 2019-06-11 12:07:56
#
#               PhySeenTime Include  ChkIn_NurSeen  NurSeen_PhySeen  \
# 1278  2019-01-17 13:21:47     Yes             15               74
# 1281  2019-01-17 13:30:32     Yes             12               87
# 6130  2019-03-19 12:13:46     Yes             16               11
# 8587  2019-04-23 14:19:55     Yes             25               47
# 10771 2019-06-11 13:47:54     Yes             28               72
#
#        WaitingTime  ...  ChkIn_Time_month  ChkIn_Time_week  ChkIn_Time_day  \
# 1278            89  ...                 1                3               3
# 1281            99  ...                 1                3               3
# 6130            27  ...                 3               12              12
# 8587            72  ...                 4               17              17
# 10771          100  ...                 6               24              24
#
#       ChkIn_Time_dayofweek ChkIn_Time_hour  PhySeenTime_month  \
# 1278                     3              11                  1
# 1281                     3              11                  1
# 6130                     1              11                  3
# 8587                     1              13                  4
# 10771                    1              12                  6
#
#        PhySeenTime_week  PhySeenTime_day  PhySeenTime_dayofweek  \
# 1278                  3                3                      3
# 1281                  3                3                      3
# 6130                 12               12                      1
# 8587                 17               17                      1
# 10771                24               24                      1
#
#        PhySeenTime_hour
# 1278                 13
# 1281                 13
# 6130                 12
# 8587                 14
# 10771                13
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Check doctor 43

# %%
df_doc_43 = df.loc[df['Phy_Name'] =='Doc43']
df_doc_43
# Out:
#              ID    Facility   Dept       Appt_DateTime          ChkIn_Time  \
# 7      30457415  Facility_1  Derma 2019-01-02 08:10:00 2019-01-02 08:00:16
# 11     29956415  Facility_1  Derma 2019-01-02 08:40:00 2019-01-02 08:16:46
# 15     29956506  Facility_1  Derma 2019-01-02 09:00:00 2019-01-02 08:18:32
# 18     29956557  Facility_1  Derma 2019-01-02 09:20:00 2019-01-02 08:20:18
# 25     30585468  Facility_1  Derma 2019-01-02 09:50:00 2019-01-02 09:30:42
# ...         ...         ...    ...                 ...                 ...
# 18510  35211639  Facility_1  Derma 2019-10-03 14:00:00 2019-10-03 14:13:25
# 18512  34639879  Facility_1  Derma 2019-10-03 14:30:00 2019-10-03 14:25:23
# 21700  31899059  Facility_1  Derma 2019-11-04 08:00:00 2019-11-04 08:00:37
# 21782  35984786  Facility_1  Derma 2019-11-04 11:40:00 2019-11-04 11:28:57
# 21837  35987548  Facility_1  Derma 2019-11-04 13:35:00 2019-11-04 13:47:53
#
#               PhySeenTime Include  ChkIn_NurSeen  NurSeen_PhySeen  \
# 7     2019-01-02 08:56:59     Yes              7               49
# 11    2019-01-02 09:17:46     Yes              4               57
# 15    2019-01-02 09:27:58     Yes             12               57
# 18    2019-01-02 09:35:43     Yes             11               64
# 25    2019-01-02 09:58:16     Yes              2               26
# ...                   ...     ...            ...              ...
# 18510 2019-10-03 14:52:12     Yes             11               28
# 18512 2019-10-03 15:23:32     Yes              7               51
# 21700 2019-11-04 08:49:14     Yes              3               46
# 21782 2019-11-04 11:36:55     Yes              5                3
# 21837 2019-11-04 13:55:30     Yes              6                2
#
#        WaitingTime  ...  ChkIn_Time_month  ChkIn_Time_week  ChkIn_Time_day  \
# 7               56  ...                 1                1               1
# 11              61  ...                 1                1               1
# 15              69  ...                 1                1               1
# 18              75  ...                 1                1               1
# 25              28  ...                 1                1               1
# ...            ...  ...               ...              ...             ...
# 18510           39  ...                10               40              40
# 18512           58  ...                10               40              40
# 21700           49  ...                11               45              45
# 21782            8  ...                11               45              45
# 21837            8  ...                11               45              45
#
#       ChkIn_Time_dayofweek ChkIn_Time_hour  PhySeenTime_month  \
# 7                        2               8                  1
# 11                       2               8                  1
# 15                       2               8                  1
# 18                       2               8                  1
# 25                       2               9                  1
# ...                    ...             ...                ...
# 18510                    3              14                 10
# 18512                    3              14                 10
# 21700                    0               8                 11
# 21782                    0              11                 11
# 21837                    0              13                 11
#
#        PhySeenTime_week  PhySeenTime_day  PhySeenTime_dayofweek  \
# 7                     1                1                      2
# 11                    1                1                      2
# 15                    1                1                      2
# 18                    1                1                      2
# 25                    1                1                      2
# ...                 ...              ...                    ...
# 18510                40               40                      3
# 18512                40               40                      3
# 21700                45               45                      0
# 21782                45               45                      0
# 21837                45               45                      0
#
#        PhySeenTime_hour
# 7                     8
# 11                    9
# 15                    9
# 18                    9
# 25                    9
# ...                 ...
# 18510                14
# 18512                15
# 21700                 8
# 21782                11
# 21837                13
#
# [1166 rows x 31 columns]

# %%
df_doc_43['Appt_DateTime_month'].value_counts()

# Doc43 has the most number of patients in February.
# Out:
# 2     215
# 7     176
# 9     155
# 3     131
# 1     127
# 4      92
# 6      87
# 5      85
# 8      78
# 10     17
# 11      3
# Name: Appt_DateTime_month, dtype: int64

# %%
df_doc_43['Appt_DateTime_dayofweek'].value_counts()

# Monday is the busiest for Doctor 43.
# Out:
# 0    266
# 2    242
# 3    241
# 6    209
# 1    208
# Name: Appt_DateTime_dayofweek, dtype: int64

# %%
df_doc_43['Appt_DateTime_hour'].value_counts()

# 8am - 10am is the busiest period for Doctor 43.
# Out:
# 9     205
# 10    198
# 8     195
# 11    192
# 12    166
# 13    105
# 14    103
# 15      2
# Name: Appt_DateTime_hour, dtype: int64

# %%
df_doc_43['WaitingTime'].quantile([0.1,.2,0.75,0.90,0.95,0.97,0.98,0.99,.999])
# Out:
# 0.100     19.00
# 0.200     28.00
# 0.750     85.75
# 0.900    121.50
# 0.950    148.75
# 0.970    176.10
# 0.980    205.80
# 0.990    231.35
# 0.999    305.69
# Name: WaitingTime, dtype: float64

# %% [markdown]
# # Create new columns:
# - chkIn_after_appointment
# - chkIn_late_minutes
# - phy_Late_minutes
# - waitingtime_groups

# %% [markdown]
# ## chkIn_after_appointment

# %%
df['chkIn_after_appointment']=df['Appt_DateTime'] < df['ChkIn_Time']
df['chkIn_after_appointment'].value_counts()

# There are 16015 appointments that patients come before their appointment time. While there are 12167 appointments that patients come after their appointment time.
# Out:
# False    15996
# True     12157
# Name: chkIn_after_appointment, dtype: int64

# %% [markdown]
# ## chkIn_late_minutes

# %%
def calculate_chkin_late_minutes(df):
    df['ChkIn_Time'] = pd.to_datetime(df['ChkIn_Time'], unit='s')
    df['Appt_DateTime'] = pd.to_datetime(df['Appt_DateTime'], unit='s')
    chkin_late_minutes = df['ChkIn_Time'] - df['Appt_DateTime']
    df['chkin_late_minutes'] = chkin_late_minutes / pd.Timedelta(minutes=1)
    return df

# %%
df = calculate_chkin_late_minutes(df)

# %% [markdown]
# ## phy_late_minutes

# %%
def calculate_phy_late_minutes(df):
    df['PhySeenTime'] = pd.to_datetime(df['PhySeenTime'], unit='s')
    t1 = df['PhySeenTime'] - df['Appt_DateTime']
    t1 = t1 / pd.Timedelta(minutes=1)
    df['phy_late_minutes'] = np.where(df['Appt_DateTime'] > df['ChkIn_Time'], t1, 0)
    return df

# %%
df = calculate_phy_late_minutes(df)

# %% [markdown]
# ## waitingtime_groups

# %%
# Group waiting time into different categories
df.loc[df['WaitingTime'].between(0, 15, 'both'), 'waitingtime_groups'] = '0 to 15 Mins'
df.loc[df['WaitingTime'].between(15, 30, 'right'), 'waitingtime_groups'] = '15 to 30 Mins'
df.loc[df['WaitingTime'].between(30, 45, 'right'), 'waitingtime_groups'] = '30 to 45 Mins'
df.loc[df['WaitingTime'].between(45, 60, 'right'), 'waitingtime_groups'] = '45 to 60 Mins'
df.loc[df['WaitingTime'] > 60, 'waitingtime_groups'] = '>60 Mins'

# %% [markdown]
# # Data Visualization

# %%
df['ChkIn_Time'] = pd.to_datetime(df['ChkIn_Time'], unit='m')
df['Appt_DateTime'] = pd.to_datetime(df['Appt_DateTime'], unit='m')

# %%
def plot_scatterplots(df,cols_to_exclude,class_col):
    # this function returns scatterplots of all the variables in the dataset
    # against the calssification variable,
    # for a quick data visualization
    import numpy as np
    import seaborn as sns
    import warnings
    warnings.filterwarnings("ignore")
    cols = df.select_dtypes(include = np.number).columns.tolist()#finding all the numerical columns from the dataframe
    X=df[cols] #creating a dataframe only with the numerical columns
    X = X[X.columns.difference(cols_to_exclude)] #columns to exclude
    for col in X.columns.difference([class_col]):
        g = sns.FacetGrid(df)
        g.map(sns.scatterplot, col, class_col)

# %%
# Plot the graphs of Features against Continuous Target Variable WaitingTime
plot_scatterplots (df,['ID', 'Include'],'WaitingTime')

# %%
df.to_csv('patient_waiting_time.csv',index=False)
